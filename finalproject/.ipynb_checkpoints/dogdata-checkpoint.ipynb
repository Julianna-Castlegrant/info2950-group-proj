# %% [markdown]
# # All Dog Reports

# %%
## this code cell is also marked as 'narrative'
import numpy as np
import pandas as pd
from matplotlib import pyplot
import seaborn

import duckdb, sqlalchemy

# %%
# %load_ext sql

# %config SqlMagic.autopandas = True
# %config SqlMagic.feedback = False
# %config SqlMagic.displaycon = False

# %sql duckdb:///:memory:

# %% [markdown]
# Research Question:

# %%
all_dogs_df = pd.read_csv("alldogsreport1.csv")
all_dogs_df.head(200)
# Out:
#        Dog Name   Tattoo  Gender Breed Color  Birthdate  \
# 0       Everest    2E322    Male    LR     Y  9/12/2022
# 1         Ellie    4E322  Female    LR     Y  9/12/2022
# 2          Echo    5E322  Female    LR     Y  9/12/2022
# 3       Eclaire    6E322  Female    LR     Y  9/12/2022
# 4         Elias    3E322    Male    LR     Y  9/12/2022
# ..          ...      ...     ...   ...   ...        ...
# 195  Carson SSD  2N01266    Male    LR     B  4/15/2022
# 196        Yeti     1Y22  Female    LR     Y  4/13/2022
# 197     Yolanda     3Y22  Female    LR     Y  4/13/2022
# 198      Yaeger     4Y22    Male    LR     Y  4/13/2022
# 199        Yoyo     5Y22  Female    LR     Y  4/13/2022
#
#                                  Dam  \
# 0             Locket - 10L318 - LRBF
# 1             Locket - 10L318 - LRBF
# 2             Locket - 10L318 - LRBF
# 3             Locket - 10L318 - LRBF
# 4             Locket - 10L318 - LRBF
# ..                               ...
# 195  Dakota - S - 4D417 - LRBF *NOP*
# 196              Janet - 2J20 - LRYF
# 197              Janet - 2J20 - LRYF
# 198              Janet - 2J20 - LRYF
# 199              Janet - 2J20 - LRYF
#
#                                              Sire  Current Status Date  \
# 0                           Everett - 1E419 - LRYM           9/12/2022
# 1                           Everett - 1E419 - LRYM           9/12/2022
# 2                           Everett - 1E419 - LRYM           9/12/2022
# 3                           Everett - 1E419 - LRYM           9/12/2022
# 4                           Everett - 1E419 - LRYM           9/12/2022
# ..                                             ...                 ...
# 195  Quincy SSD Shiloh II PADS - QUINCY SSD - LRBM           6/23/2022
# 196                           Garcia - 4G16 - LRYM            6/8/2022
# 197                           Garcia - 4G16 - LRYM           7/15/2022
# 198                           Garcia - 4G16 - LRYM           6/28/2022
# 199                           Garcia - 4G16 - LRYM            6/9/2022
#
#                 Status                             Region Graduation Date  \
# 0    Too Young to Test                                NaN             NaN
# 1    Too Young to Test                                NaN             NaN
# 2    Too Young to Test                                NaN             NaN
# 3    Too Young to Test                                NaN             NaN
# 4    Too Young to Test                                NaN             NaN
# ..                 ...                                ...             ...
# 195       Other School                                NaN             NaN
# 196      Puppy Raising      Columbus Puppy Raising Region             NaN
# 197      Puppy Raising    Eastern MA Puppy Raising Region             NaN
# 198      Puppy Raising    Central CT Puppy Raising Region             NaN
# 199      Puppy Raising  Rhode Island Puppy Raising Region             NaN
#
#     Graduate Team Location
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ..                     ...
# 195                    NaN
# 196                    NaN
# 197                    NaN
# 198                    NaN
# 199                    NaN
#
# [200 rows x 13 columns]

# %%
print(list(all_dogs_df.columns))
# Out:
# ['Dog Name', 'Tattoo', 'Gender', 'Breed', 'Color', 'Birthdate', 'Dam', 'Sire ', 'Current Status Date', 'Status', 'Region', 'Graduation Date', 'Graduate Team Location']

# %%
regional_dogs = all_dogs_df.groupby("Region")
regional_dogs.head(200)
# Out:
#       Dog Name Tattoo  Gender Breed Color Birthdate                       Dam  \
# 82       Nikon  2NN22    Male    LR     B  7/5/2022    Madeline - 7M20 - LRYF
# 83        Nova  3NN22  Female    LR     B  7/5/2022    Madeline - 7M20 - LRYF
# 85       Mitch  3MM22    Male    LR     B  7/2/2022       Dawn - 1DD20 - LRYF
# 86    Maverick  2MM22    Male    LR     Y  7/2/2022       Dawn - 1DD20 - LRYF
# 87     Maguire  4MM22    Male    LR     Y  7/2/2022       Dawn - 1DD20 - LRYF
# ...        ...    ...     ...   ...   ...       ...                       ...
# 1147     Baron   4B20    Male    LR     B  1/7/2020        Lark - 4L18 - LRBF
# 1149   Bramble   8B20    Male    LR     Y  1/7/2020        Lark - 4L18 - LRBF
# 1150     Buddy   9B20    Male    LR     B  1/7/2020        Lark - 4L18 - LRBF
# 1151    Barney  10B20    Male    LR     Y  1/7/2020        Lark - 4L18 - LRBF
# 1153      Andy   2A20    Male    LR     B  1/6/2020  Wanda - S - 2WW15 - LRBF
#
#                     Sire  Current Status Date         Status  \
# 82    Odin - 5OO19 - LRBM            9/3/2022  Puppy Raising
# 83    Odin - 5OO19 - LRBM            9/2/2022  Puppy Raising
# 85    Dover - 3D19 - LRBM           8/28/2022  Puppy Raising
# 86    Dover - 3D19 - LRBM           8/28/2022  Puppy Raising
# 87    Dover - 3D19 - LRBM           8/28/2022  Puppy Raising
# ...                   ...                 ...            ...
# 1147  Finn - 7F315 - LRYM          10/18/2021       Breeding
# 1149  Finn - 7F315 - LRYM           2/22/2022       Released
# 1150  Finn - 7F315 - LRYM           2/15/2022    In Training
# 1151  Finn - 7F315 - LRYM           5/27/2021       Released
# 1153   Joe - 4JJ13 - LRBM           6/13/2022       Released
#
#                                    Region Graduation Date  \
# 82       Northern CT Puppy Raising Region             NaN
# 83              SWCT Puppy Raising Region             NaN
# 85        Eastern MA Puppy Raising Region             NaN
# 86          Columbus Puppy Raising Region             NaN
# 87          Delmarva Puppy Raising Region             NaN
# ...                                   ...             ...
# 1147      Central NY Puppy Raising Region             NaN
# 1149  Prince William Puppy Raising Region             NaN
# 1150  Cleveland West Puppy Raising Region             NaN
# 1151        Dominion Puppy Raising Region             NaN
# 1153      Eastern MA Puppy Raising Region             NaN
#
#      Graduate Team Location
# 82                      NaN
# 83                      NaN
# 85                      NaN
# 86                      NaN
# 87                      NaN
# ...                     ...
# 1147                    NaN
# 1149                    NaN
# 1150                    NaN
# 1151                    NaN
# 1153                    NaN
#
# [745 rows x 13 columns]

# %%
all_dogs_df.loc[all_dogs_df['Status']=='Graduated'].sort_values(by=['Dam'])
# Out:
#       Dog Name Tattoo  Gender Breed Color  Birthdate  \
# 954   Fantasia  1FF20  Female    LR     Y  4/24/2020
# 1043        6/4/2022         Georgia, Brooklet
# 918         5/3/2022  Massachusetts, Brookline
# 1005       1/15/2022  South Dakota, Vermillion
# 1134       4/22/2022      Minnesota, Richfield
# 1014       8/16/2022  Massachusetts, Brookline
# 974         5/7/2022            Oklahoma, Enid
# 942        3/18/2022       New York, Woodhaven
# 943        6/17/2022        California, Sonoma
# 1092       5/18/2022             Texas, Dallas
# 1139       6/17/2022      Wisconsin, Milwaukee
# 1125      10/11/2021      Wisconsin, Milwaukee

# %%
all_dogs_df
# Out:
#           Dog Name Tattoo  Gender Breed Color  Birthdate  \
# 0          Everest  2E322    Male    LR     Y  9/12/2022
# 1            Ellie  4E322  Female    LR     Y  9/12/2022
# 2             Echo  5E322  Female    LR     Y  9/12/2022
# 3          Eclaire  6E322  Female    LR     Y  9/12/2022
# 4            Elias  3E322    Male    LR     Y  9/12/2022
# ...            ...    ...     ...   ...   ...        ...
# 1149       Bramble   8B20    Male    LR     Y   1/7/2020
# 1150         Buddy   9B20    Male    LR     B   1/7/2020
# 1151        Barney  10B20    Male    LR     Y   1/7/2020
# 1152  Amos (Noche)   1A20    Male    LR     B   1/6/2020
# 1153          Andy   2A20    Male    LR     B   1/6/2020
#
#                            Dam                   Sire  Current Status Date  \
# 0       Locket - 10L318 - LRBF  Everett - 1E419 - LRYM           9/12/2022
# 1       Locket - 10L318 - LRBF  Everett - 1E419 - LRYM           9/12/2022
# 2       Locket - 10L318 - LRBF  Everett - 1E419 - LRYM           9/12/2022
# 3       Locket - 10L318 - LRBF  Everett - 1E419 - LRYM           9/12/2022
# 4       Locket - 10L318 - LRBF  Everett - 1E419 - LRYM           9/12/2022
# ...                        ...                     ...                 ...
# 1149        Lark - 4L18 - LRBF     Finn - 7F315 - LRYM           2/22/2022
# 1150        Lark - 4L18 - LRBF     Finn - 7F315 - LRYM           2/15/2022
# 1151        Lark - 4L18 - LRBF     Finn - 7F315 - LRYM           5/27/2021
# 1152  Wanda - S - 2WW15 - LRBF      Joe - 4JJ13 - LRBM            3/4/2020
# 1153  Wanda - S - 2WW15 - LRBF      Joe - 4JJ13 - LRBM           6/13/2022
#
#                  Status                               Region Graduation Date  \
# 0     Too Young to Test                                  NaN             NaN
# 1     Too Young to Test                                  NaN             NaN
# 2     Too Young to Test                                  NaN             NaN
# 3     Too Young to Test                                  NaN             NaN
# 4     Too Young to Test                                  NaN             NaN
# ...                 ...                                  ...             ...
# 1149           Released  Prince William Puppy Raising Region             NaN
# 1150        In Training  Cleveland West Puppy Raising Region             NaN
# 1151           Released        Dominion Puppy Raising Region             NaN
# 1152           Released                                  NaN             NaN
# 1153           Released      Eastern MA Puppy Raising Region             NaN
#
#      Graduate Team Location
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ...                     ...
#
# 918             5/3/2022          Graduated
# 974             5/7/2022          Graduated
# 954            6/15/2022          Graduated
# 1139           6/18/2022          Graduated
# 943            6/18/2022          Graduated
# 1034           6/18/2022          Graduated
# 1021            9/1/2022            Retired
# 1043            6/4/2022          Graduated
# 1090            9/2/2022        In Training
# 1014           8/16/2022          Graduated
# 900            9/13/2022           In Class
# 1017           9/13/2022           In Class
# 0              9/12/2022  Too Young to Test
# 1              9/12/2022  Too Young to Test
#
#                                        Region Graduation Date  \
# 1005  Westchester County Puppy Raising Region       1/15/2022
# 1125         Northern CT Puppy Raising Region      10/11/2021
# 1042         Northern CT Puppy Raising Region       2/14/2022
# 942           Central NY Puppy Raising Region       3/18/2022
# 1134                 Bay Puppy Raising Region       4/22/2022
# 1092         Northern CT Puppy Raising Region       5/18/2022
# 918             Dominion Puppy Raising Region        5/3/2022
# 974            Baltimore Puppy Raising Region        5/7/2022
# 954         Rhode Island Puppy Raising Region       6/15/2022
# 1139      Cleveland East Puppy Raising Region       6/17/2022
# 943           Central NY Puppy Raising Region       6/17/2022
# 1034       New Hampshire Puppy Raising Region       6/17/2022
# 1021           Monroe NY Puppy Raising Region        6/4/2022
# 1043      Cleveland West Puppy Raising Region        6/4/2022
# 1090          Montgomery Puppy Raising Region        7/2/2022
# 1014      Cleveland West Puppy Raising Region       8/16/2022
# 900   Westchester County Puppy Raising Region       9/23/2022
# 1017         Dutchess NY Puppy Raising Region       9/23/2022
# 0                                         NaN             NaN
# 1                                         NaN             NaN
#
#         Graduate Team Location
# 1005  South Dakota, Vermillion
# 1125      Wisconsin, Milwaukee
# 1042       Vermont, Colchester
# 942        New York, Woodhaven
# 1134      Minnesota, Richfield
# 1092             Texas, Dallas
# 918   Massachusetts, Brookline
# 974             Oklahoma, Enid
# 954            Indiana, Kokomo
# 1139      Wisconsin, Milwaukee
# 943         California, Sonoma
# 1034      Kentucky, Louisville
# 1021          Maine, Kennebunk
# 1043         Georgia, Brooklet
# 1090          Colorado, Denver
# 1014  Massachusetts, Brookline
# 900         Florida, Lady Lake
# 1017         Illinois, Chicago
# 0                          NaN
# 1                          NaN

# %%
all_dogs_revised_df = pd.read_csv("alldogsreport-revised.csv")
all_dogs_revised_df.head(200)
print(all_dogs_revised_df['Status'][1021])
# Out:
# Graduated

# %%
all_dogs_revised_df['Pass_Fail'] = (all_dogs_revised_df['Status'] == 'Graduated') | (all_dogs_revised_df['Status'] == 'Other School')
all_dogs_dropcol_df = all_dogs_revised_df.drop(columns = ['Graduation Date', 'Graduate Team Location'])
all_dogs_dropcol_df['Birthdate'] = pd.to_datetime(all_dogs_dropcol_df['Birthdate'])
all_dogs_dropcol_df['Current Status Date'] = pd.to_datetime(all_dogs_dropcol_df['Current Status Date'])
all_dogs_dropcol_df
clean_dogs_df = all_dogs_dropcol_df.loc[(all_dogs_dropcol_df['Status']=='Graduated') | (all_dogs_dropcol_df['Status']=='Released') | (all_dogs_dropcol_df['Status']=='Other School') | (all_dogs_dropcol_df['Status']=='In Training')]
#clean_dogs_df.head(100)
#clean_dogs_df.loc['Released']
#display(clean_dogs_df)
display(clean_dogs_df.loc[[1021]])
# Out:
#      Dog Name Tattoo Gender Breed Color  Birthdate                   Dam  \
# 1021   Rooney   9R20   Male    LR     Y 2020-03-07  Tiara - 6TT15 - LRBF
#
#                      Sire  Current Status Date     Status  \
# 1021  Kisco - 6KK18 - LRYM          2022-09-01  Graduated
#
#                               Region  Pass_Fail
# 1021  Monroe NY Puppy Raising Region       True

# %%
clean_dogs_df
# Out:
#            Dog Name Tattoo  Gender Breed Color  Birthdate  \
# 76        Priscilla  5PP22  Female    LR     B 2022-07-19
# 80             Nana  4NN22  Female    LR     B 2022-07-05
# 84            Nifty  5NN22  Female    LR     B 2022-07-05
# 90    Moana (Dugan)  1MM22  Female    LR     B 2022-07-02
# 95            Leone  2LL22    Male    LR     B 2022-06-21
# ...             ...    ...     ...   ...   ...        ...
# 1149        Bramble   8B20    Male    LR     Y 2020-01-07
# 1150          Buddy   9B20    Male    LR     B 2020-01-07
# 1151         Barney  10B20    Male    LR     Y 2020-01-07
# 1152   Amos (Noche)   1A20    Male    LR     B 2020-01-06
# 1153           Andy   2A20    Male    LR     B 2020-01-06
#
#                            Dam                 Sire  Current Status Date  \
# 76        Zelda - 1Z319 - LRBF  Gerald - 7G20 - LRYM          2022-09-12
# 80      Madeline - 7M20 - LRYF   Odin - 5OO19 - LRBM          2022-08-29
# 84      Madeline - 7M20 - LRYF   Odin - 5OO19 - LRBM          2022-08-29
# 90         Dawn - 1DD20 - LRYF   Dover - 3D19 - LRBM          2022-08-25
# 95          Via - 6VV18 - LRBF  Elrod - 6E319 - LRBM          2022-08-15
# ...                        ...                   ...                 ...
# 1149        Lark - 4L18 - LRBF   Finn - 7F315 - LRYM          2022-02-22
# 1150        Lark - 4L18 - LRBF   Finn - 7F315 - LRYM          2022-02-15
# 1151        Lark - 4L18 - LRBF   Finn - 7F315 - LRYM          2021-05-27
# 1152  Wanda - S - 2WW15 - LRBF    Joe - 4JJ13 - LRBM          2020-03-04
# 1153  Wanda - S - 2WW15 - LRBF    Joe - 4JJ13 - LRBM          2022-06-13
#
#            Status                               Region  Pass_Fail
# 76       Released                                  NaN      False
# 80       Released                                  NaN      False
# 84       Released                                  NaN      False
# 90       Released                                  NaN      False
# 95       Released                                  NaN      False
# ...           ...                                  ...        ...
# 1149     Released  Prince William Puppy Raising Region      False
# 1150  In Training  Cleveland West Puppy Raising Region      False
# 1151     Released        Dominion Puppy Raising Region      False
# 1152     Released                                  NaN      False
# 1153     Released      Eastern MA Puppy Raising Region      False
#
# [612 rows x 12 columns]

# %%
clean_dogs_df.to_csv('clean_dog_data.csv')

# %%
all_dogs_revised_df['Status'].unique()
# Out:
# array(['Too Young to Test', 'Ready for Puppy Raiser', 'Released',
#        'Puppy Raising', 'Other School', nan, 'In Training', 'Breed Eval',
#        'Breeding', 'Graduated'], dtype=object)

# %% [markdown]
# Starting to create df for those who have not been testsed (Puppy Raising)- Data to run model on:

# %%
dogs_to_predict_df = all_dogs_dropcol_df.loc[(all_dogs_dropcol_df['Status']=='Too Young to Test') | (all_dogs_dropcol_df['Status']=='Ready for Puppy Raiser') | (all_dogs_dropcol_df['Status']=='Puppy Raising')]
#dogs_to_predict_df['Birthdate'] = pd.to_datetime(dogs_to_predict_df['Birthdate'])
dogs_to_predict_df = dogs_to_predict_df.drop(columns = ['Pass_Fail'])
dogs_to_predict_df
# Out:
#     Dog Name Tattoo  Gender Breed Color  Birthdate                     Dam  \
# 0    Everest  2E322    Male    LR     Y 2022-09-12  Locket - 10L318 - LRBF
# 1      Ellie  4E322  Female    LR     Y 2022-09-12  Locket - 10L318 - LRBF
# 2       Echo  5E322  Female    LR     Y 2022-09-12  Locket - 10L318 - LRBF
# 3    Eclaire  6E322  Female    LR     Y 2022-09-12  Locket - 10L318 - LRBF
# 4      Elias  3E322    Male    LR     Y 2022-09-12  Locket - 10L318 - LRBF
# ..       ...    ...     ...   ...   ...        ...                     ...
# 754  Grayson   1G21    Male    LR     B 2021-03-31  Fortune - 4F318 - LRYF
# 755    Gibbs   2G21    Male    LR     B 2021-03-31  Fortune - 4F318 - LRYF
# 756   Gatsby   3G21    Male    LR     B 2021-03-31  Fortune - 4F318 - LRYF
# 759   Gideon   4G21    Male    LR     B 2021-03-31  Fortune - 4F318 - LRYF
# 762   Grover   9G21    Male    LR     B 2021-03-31  Fortune - 4F318 - LRYF
#
#                       Sire  Current Status Date             Status  \
# 0    Everett - 1E419 - LRYM          2022-09-12  Too Young to Test
# 1    Everett - 1E419 - LRYM          2022-09-12  Too Young to Test
# 2    Everett - 1E419 - LRYM          2022-09-12  Too Young to Test
# 3    Everett - 1E419 - LRYM          2022-09-12  Too Young to Test
# 4    Everett - 1E419 - LRYM          2022-09-12  Too Young to Test
# ..                      ...                 ...                ...
# 754   Dasher - 6D418 - LRBM          2021-06-10      Puppy Raising
# 755   Dasher - 6D418 - LRBM          2021-06-05      Puppy Raising
# 756   Dasher - 6D418 - LRBM          2021-06-05      Puppy Raising
# 759   Dasher - 6D418 - LRBM          2021-06-05      Puppy Raising
# 762   Dasher - 6D418 - LRBM          2021-06-05      Puppy Raising
#
#                                  Region
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ..                                  ...
# 754     Central NY Puppy Raising Region
# 755       Colorado Puppy Raising Region
# 756  New Hampshire Puppy Raising Region
# 759      Baltimore Puppy Raising Region
# 762       Richmond Puppy Raising Region
#
# [500 rows x 11 columns]

# %%
dogs_to_predict_df.to_csv('predict_dog_data.csv')

# %% [markdown]
# Data Description:

# %% [markdown]
# Exploratory Data Analysis

# %%
clean_dogs_df[['Current Status Date', 'Pass_Fail']].groupby(clean_dogs_df['Current Status Date'].dt.year).sum()
# Out:
#                      Pass_Fail
# Current Status Date
# 2020                         8
# 2021                        28
# 2022                       103

# %%
pass_dogs_df = clean_dogs_df.loc[(all_dogs_dropcol_df['Pass_Fail']==1)]
pass_dogs_df['Gender'].value_counts()
# Out:
# Male      72
# Female    67
# Name: Gender, dtype: int64
